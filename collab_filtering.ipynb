# %% [markdown]
# # Recommendations: Collaborative Filtering
#
# This notebook reads in a .csv file of a user's ratings across several books (low and/or high ratings) to generate book recommendations using a collaborative filtering method.

# %%
# Read in my favourite books
import pandas as pd

my_books = pd.read_csv("liked_books_kevin.csv", index_col=0)
my_books["book_id"] = my_books["book_id"].astype(str)
my_books
# Out:
#     user_id   book_id  rating  \
# 0        -1   1334340       5
# 1        -1    224516       5
# 2        -1  12170167       5
# 3        -1    241798       5
# 4        -1    437143       5
# 6        -1      3869       5
# 7        -1   8492907       5
# 8        -1     22543       5
# 9        -1   1125545       5
# 10       -1  22841994       5
#
#                                                 title
# 0                                          The Hobbit
# 1                               The Falcon's Malteser
# 2                                  A Study in Scarlet
# 3   The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 4                A Short History of Nearly Everything
# 6                             A Brief History of Time
# 7   Physics of the Future: How Science Will Shape ...
# 8   Death by Black Hole - And Other Cosmic Quandaries
# 9                             The Wind in the Willows
# 10           Harry Potter and the Philosopher's Stone

# %%
book_set = set(my_books["book_id"])

# %%
# Read in book ID mapping
csv_book_mapping = {}

with open("book_id_map.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
# Read in Goodreads user interactions that overlap with my books
overlap_users = {}

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

len(overlap_users)
# Out:
# 36159

# %%
# Filter the top 10% of overlapping users
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/10])
len(filtered_overlap_users)
# Out:
# 2825

# %%
# Import top users interactions
interactions_list = []

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.strip().split(",")
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

len(interactions_list)
# Out:
# 4627351

# %%
# Rearrange data and ensure data types are correct
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
interactions = pd.concat([my_books[["user_id", "book_id","rating"]],interactions])
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])
interactions
# Out:
#         user_id   book_id  rating
# 0            -1   1334340       5
# 1            -1    224516       5
# 2            -1  12170167       5
# 3            -1    241798       5
# 4            -1    437143       5
# ...         ...       ...     ...
# 4627346  875462   5600892       5
# 4627347  875462  10290474       5
# 4627348  875462  10290471       5
# 4627349  875462   2961821       5
# 4627350  875462   2961822       5
#
# [4627361 rows x 3 columns]

# %%
# Convert user IDs to rows that can be assigned to a matrix
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes
interactions
# Out:
#         user_id   book_id  rating  user_index  book_index
# 0            -1   1334340       5           0       95847
# 1            -1    224516       5           0      329566
# 2            -1  12170167       5           0       59883
# 3            -1    241798       5           0      376495
# 4            -1    437143       5           0      580779
# ...         ...       ...     ...         ...         ...
# 4627346  875462   5600892       5        2742      610108
# 4627347  875462  10290474       5        2742        7909
# 4627348  875462  10290471       5        2742        7908
# 4627349  875462   2961821       5        2742      482938
# 4627350  875462   2961822       5        2742      482939
#
# [4627361 rows x 5 columns]

# %%
# Convert users and books into a compressed sparse row matrix
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))
ratings_mat = ratings_mat_coo.tocsr()

# %%
interactions[interactions["user_id"]=="-1"]
# Out:
#    user_id   book_id  rating  user_index  book_index
# 0       -1   1334340       5           0       95847
# 1       -1    224516       5           0      329566
# 2       -1  12170167       5           0       59883
# 3       -1    241798       5           0      376495
# 4       -1    437143       5           0      580779
# 6       -1      3869       5           0      567687
# 7       -1   8492907       5           0      724471
# 8       -1     22543       5           0      331972
# 9       -1   1125545       5           0       35230
# 10      -1  22841994       5           0      341706

# %%
# Generate similarities of users compared to us (my_index)
from sklearn.metrics.pairwise import cosine_similarity

my_index = 0
similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
# Find positions of 15 most similar users
import numpy as np
indices = np.argpartition(similarity, -20)[-20:]
indices
# Out:
# array([2422, 2242, 2529, 2686, 2685, 2320, 2689, 2427, 2436, 2446, 2520,
#        2684, 2397, 2261, 2687, 2661, 2351, 2447, 2402,    0], dtype=int64)

# %%
# Remove our own user interactions
similar_users = interactions[interactions["user_index"].isin(indices)].copy()
similar_users = similar_users[similar_users["user_id"] != "-1"]
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 4613994  465435  11084145       0        2242       30118
# 4613995  465435      1845       0        2242      243138
# 4613996  465435     10884       0        2242       24951
# 4613997  465435     40929       0        2242      573917
# 4613998  465435       960       4        2242      758616
# ...         ...       ...     ...         ...         ...
# 4625304  848000   4005310       3        2689      571655
# 4625305  848000     98685       3        2689      768740
# 4625306  848000   2330343       4        2689      355903
# 4625307  848000    150129       4        2689      135239
# 4625308  848000    151132       4        2689      136350
#
# [627 rows x 5 columns]

# %%
# Reassign user IDs by grouping
book_recs = similar_users.groupby("book_id").rating.agg(["count", "mean"])
book_recs
# Out:
#          count  mean
# book_id
# 100006       1   0.0
# 100641       1   5.0
# 100915       1   3.0
# 10210        1   0.0
# 10238        1   0.0
# ...        ...   ...
# 98685        1   3.0
# 99218        1   4.0
# 99219        1   4.0
# 99220        1   4.0
# 99328        1   0.0
#
# [422 rows x 2 columns]

# %%
# Generate all relevant book recommendations
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")
book_recs
# Out:
#     book_id  count  mean                                              title  \
# 0    100006      1   0.0  Schrodinger's Kittens and the Search for Reali...
# 1    100641      1   5.0  Beyond Star Trek: From Alien Invasions to the ...
# 2    100915      1   3.0  The Lion, the Witch, and the Wardrobe (Chronic...
# 3     10210      1   0.0                                          Jane Eyre
# 4     10238      1   0.0  The Tao of Physics: An Exploration of the Para...
# ..      ...    ...   ...                                                ...
# 412   98685      1   3.0    Genius: The Life and Science of Richard Feynman
# 413   99218      1   4.0          The Machine Crusade (Legends of Dune, #2)
# 414   99219      1   4.0          The Butlerian Jihad (Legends of Dune, #1)
# 415   99220      1   4.0         The Battle of Corrin (Legends of Dune, #3)
# 416   99328      1   0.0                                     The Discourses
#
#      ratings                                                url  \
# 0       1095  https://www.goodreads.com/book/show/100006.Sch...
# 1        334  https://www.goodreads.com/book/show/100641.Bey...
# 2    1575387  https://www.goodreads.com/book/show/100915.The...
# 3    1207986  https://www.goodreads.com/book/show/10210.Jane...
# 4      12814  https://www.goodreads.com/book/show/10238.The_...
# ..       ...                                                ...
# 412    15189   https://www.goodreads.com/book/show/98685.Genius
# 413    10250  https://www.goodreads.com/book/show/99218.The_...
# 414    15003  https://www.goodreads.com/book/show/99219.The_...
# 415     8895  https://www.goodreads.com/book/show/99220.The_...
# 416     5817  https://www.goodreads.com/book/show/99328.The_...
#
#                                            cover_image  \
# 0    https://images.gr-assets.com/books/1344269008m...
# 1    https://s.gr-assets.com/assets/nophoto/book/11...
# 2    https://images.gr-assets.com/books/1353029077m...
# 3    https://images.gr-assets.com/books/1327867269m...
# 4    https://images.gr-assets.com/books/1327908532m...
# ..                                                 ...
# 413              the machine crusade legends of dune 2    9.756098e-05
# 414              the butlerian jihad legends of dune 1    6.665334e-05
# 415             the battle of corrin legends of dune 3    1.124227e-04
# 416                                     the discourses    1.719099e-04
#
#         score
# 0    0.000000
# 1    0.014970
# 2    0.000002
# 3    0.000000
# 4    0.000000
# ..        ...
# 412  0.000198
# 413  0.000390
# 414  0.000267
# 415  0.000450
# 416  0.000000
#
# [414 rows x 10 columns]

# %%
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]","",regex=True).str.lower()
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)

# %%
# Filter out my book selections, recommendation count, and mean rating
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]
book_recs = book_recs[book_recs["count"] > 1]
book_recs = book_recs[book_recs["mean"] > 4]
top_recs = book_recs.sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

# %%
top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e40b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e40b8_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_e40b8_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_e40b8_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_e40b8_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_e40b8_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_e40b8_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_e40b8_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_e40b8_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_e40b8_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_e40b8_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e40b8_level0_row0" class="row_heading level0 row0" >327</th>
#       <td id="T_e40b8_row0_col0" class="data row0 col0" >5958783</td>
#       <td id="T_e40b8_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_e40b8_row0_col2" class="data row0 col2" >5.000000</td>
#       <td id="T_e40b8_row0_col3" class="data row0 col3" >Why Does E=mc²?</td>
#       <td id="T_e40b8_row0_col4" class="data row0 col4" >4951</td>
#       <td id="T_e40b8_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/5958783-why-does-e-mc">Goodreads</a></td>
#       <td id="T_e40b8_row0_col6" class="data row0 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_e40b8_row0_col7" class="data row0 col7" >why does emc</td>
#       <td id="T_e40b8_row0_col8" class="data row0 col8" >0.000808</td>
#       <td id="T_e40b8_row0_col9" class="data row0 col9" >0.004040</td>
#     </tr>
#     <tr>
#       <th id="T_e40b8_level0_row1" class="row_heading level0 row1" >206</th>
#       <td id="T_e40b8_row1_col0" class="data row1 col0" >2802</td>
#       <td id="T_e40b8_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_e40b8_row1_col2" class="data row1 col2" >4.500000</td>
#       <td id="T_e40b8_row1_col3" class="data row1 col3" >E=mc²: A Biography of the World's Most Famous Equation</td>
#       <td id="T_e40b8_row1_col4" class="data row1 col4" >5641</td>
#       <td id="T_e40b8_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2802.E_mc_">Goodreads</a></td>
#       <td id="T_e40b8_row1_col6" class="data row1 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_e40b8_row1_col7" class="data row1 col7" >emc a biography of the worlds most famous equation</td>
#       <td id="T_e40b8_row1_col8" class="data row1 col8" >0.000709</td>
#       <td id="T_e40b8_row1_col9" class="data row1 col9" >0.003191</td>
#     </tr>
#     <tr>
#       <th id="T_e40b8_level0_row2" class="row_heading level0 row2" >146</th>
#       <td id="T_e40b8_row2_col0" class="data row2 col0" >2094</td>
#       <td id="T_e40b8_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_e40b8_row2_col2" class="data row2 col2" >4.333333</td>
#       <td id="T_e40b8_row2_col3" class="data row2 col3" >A Briefer History of Time</td>
#       <td id="T_e40b8_row2_col4" class="data row2 col4" >20217</td>
#       <td id="T_e40b8_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2094.A_Briefer_History_of_Time">Goodreads</a></td>
#       <td id="T_e40b8_row2_col6" class="data row2 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_e40b8_row2_col7" class="data row2 col7" >a briefer history of time</td>
#       <td id="T_e40b8_row2_col8" class="data row2 col8" >0.000445</td>
#       <td id="T_e40b8_row2_col9" class="data row2 col9" >0.001929</td>
#     </tr>
#     <tr>
#       <th id="T_e40b8_level0_row3" class="row_heading level0 row3" >364</th>
#       <td id="T_e40b8_row3_col0" class="data row3 col0" >73945</td>
#       <td id="T_e40b8_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_e40b8_row3_col2" class="data row3 col2" >4.500000</td>
#       <td id="T_e40b8_row3_col3" class="data row3 col3" >Apology</td>
#       <td id="T_e40b8_row3_col4" class="data row3 col4" >19111</td>
#       <td id="T_e40b8_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/73945.Apology">Goodreads</a></td>
#       <td id="T_e40b8_row3_col6" class="data row3 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_e40b8_row3_col7" class="data row3 col7" >apology</td>
#       <td id="T_e40b8_row3_col8" class="data row3 col8" >0.000209</td>
#       <td id="T_e40b8_row3_col9" class="data row3 col9" >0.000942</td>
#     </tr>
#     <tr>
#       <th id="T_e40b8_level0_row4" class="row_heading level0 row4" >46</th>
#       <td id="T_e40b8_row4_col0" class="data row4 col0" >12391521</td>
#       <td id="T_e40b8_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_e40b8_row4_col2" class="data row4 col2" >4.500000</td>
#       <td id="T_e40b8_row4_col3" class="data row4 col3" >The Psychopath Test: A Journey Through the Madness Industry</td>
#       <td id="T_e40b8_row4_col4" class="data row4 col4" >46907</td>
#       <td id="T_e40b8_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/12391521-the-psychopath-test">Goodreads</a></td>
#       <td id="T_e40b8_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1364166270m/12391521.jpg" width=50></img></td>
#       <td id="T_e40b8_row4_col7" class="data row4 col7" >the psychopath test a journey through the madness industry</td>
#       <td id="T_e40b8_row4_col8" class="data row4 col8" >0.000085</td>
#       <td id="T_e40b8_row4_col9" class="data row4 col9" >0.000384</td>
#     </tr>
#     <tr>
#       <th id="T_e40b8_level0_row5" class="row_heading level0 row5" >220</th>
#       <td id="T_e40b8_row5_col0" class="data row5 col0" >30289</td>
#       <td id="T_e40b8_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_e40b8_row5_col2" class="data row5 col2" >4.500000</td>
#       <td id="T_e40b8_row5_col3" class="data row5 col3" >The Republic</td>
#       <td id="T_e40b8_row5_col4" class="data row5 col4" >113894</td>
#       <td id="T_e40b8_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/30289.The_Republic">Goodreads</a></td>
#       <td id="T_e40b8_row5_col6" class="data row5 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_e40b8_row5_col7" class="data row5 col7" >the republic</td>
#       <td id="T_e40b8_row5_col8" class="data row5 col8" >0.000035</td>
#       <td id="T_e40b8_row5_col9" class="data row5 col9" >0.000158</td>
#     </tr>
#     <tr>
#       <th id="T_e40b8_level0_row6" class="row_heading level0 row6" >60</th>
#       <td id="T_e40b8_row6_col0" class="data row6 col0" >13335037</td>
#       <td id="T_e40b8_row6_col1" class="data row6 col1" >2</td>
#       <td id="T_e40b8_row6_col2" class="data row6 col2" >4.500000</td>
#       <td id="T_e40b8_row6_col3" class="data row6 col3" >Divergent (Divergent, #1)</td>
#       <td id="T_e40b8_row6_col4" class="data row6 col4" >1962813</td>
#       <td id="T_e40b8_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/13335037-divergent">Goodreads</a></td>
#       <td id="T_e40b8_row6_col6" class="data row6 col6" ><img src="https://images.gr-assets.com/books/1328559506m/13335037.jpg" width=50></img></td>
#       <td id="T_e40b8_row6_col7" class="data row6 col7" >divergent divergent 1</td>
#       <td id="T_e40b8_row6_col8" class="data row6 col8" >0.0000
